# %% [markdown]
# # Knowledge Graph Exploration
# Used for verifying graph structural integrity (DI-01) and manual contradiction injection.

# %%
from ai_reasoning.core.graph import KnowledgeGraph
from ai_reasoning.core.node import KnowledgeNode
graph = KnowledgeGraph()
# Manually seed nodes for visualization test
